# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshitija0707/Kshitija0707/blob/main/WebScraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

def scrape_website(url):
    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find specific data on the page
        links = soup.find_all('a')

        # Extract and print the href attribute of each link
        for link in links:
            href = link.get('href')
            if href:
                print(href)
    else:
        print("Failed to fetch the web page.")

def main():
    # Specify the URL of the website to scrape
    url = "https://github.com/Kshitija0707/Kshitija0707"

    # Call the function to scrape the website
    scrape_website(url)

if __name__ == "__main__":
    main()
# Out:
# #start-of-content
# https://github.com/
# /login?return_to=https%3A%2F%2Fgithub.com%2FKshitija0707%2FKshitija0707
# /features/actions
# /features/packages
# /features/security
# /features/codespaces
# /features/copilot
# /features/code-review
# /features/issues
# /features/discussions
# /features
# https://docs.github.com
# https://skills.github.com/
# https://github.blog
# /enterprise
# /team
# /enterprise/startups
# https://education.github.com
# /solutions/ci-cd/
# https://resources.github.com/devops/
# https://resources.github.com/devops/fundamentals/devsecops/
# https://resources.github.com/learn/pathways/
# https://resources.github.com/
# /customer-stories
# https://partner.github.com/
# /sponsors
# /readme
# /topics
# /trending
# /collections
# /pricing
# https://docs.github.com/search-github/github-code-search/understanding-github-code-search-syntax
# https://docs.github.com/search-github/github-code-search/understanding-github-code-search-syntax
# ...
